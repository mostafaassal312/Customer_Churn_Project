# %%
import sys
import os
import pandas as pd

# Add src to path
sys.path.append(os.path.abspath(os.path.join('..')))

from src.data_engine import generate_churn_data

# Generate Data
df = generate_churn_data(num_customers = 2000, output_path = '../data/raw/telecom_churn_v1.csv')

# Check the Churn Balance 
print("\n--- Churn Distribution ---")
print(df['Churn'].value_counts(normalize = True))

display(df.head())
# Out:
# [INFO] Generating data for 2000 customers...
# [SUCCESS] Data saved to ../data/raw/telecom_churn_v1.csv
#
# --- Churn Distribution ---
# Churn
# No     0.615
# Yes    0.385
# Name: proportion, dtype: float64
#    CustomerID  Tenure_Months        Contract InternetService  MonthlyCharges  \
# 0  CUST-00001             52        Two year             DSL           51.49
# 1  CUST-00002             15        Two year             DSL           58.92
# 2  CUST-00003             72  Month-to-month             DSL           52.90
# 3  CUST-00004             61  Month-to-month     Fiber optic           91.89
# 4  CUST-00005             21        One year              No           21.72
#
#   Churn
# 0    No
# 1    No
# 2    No
# 3    No
# 4   Yes
